# %%
# !echo "`cd /media/kalkyl-glob/github/masm-vali/masmvali/ && git log -1`"
# Out:
# commit fc0095f621b2e72de09de75c3618b3a66dd1d578Author: Ino de Bruijn <ino.debruijn@scilifelab.se>Date:   Fri Apr 26 17:16:43 2013 +0200    Changes validation class so it can be more easily used in the notebook for plotting. Adds a bunch of calculated metrics to the coords class for easy plotting.

# %%
import sysimport osimport resys.path.append('/media/kalkyl-glob/github/masm-vali/masmvali/')import assemblyreload(assembly)import nucmerreload(nucmer)import refgenomereload(refgenome)import validationreload(validation)
# Out:
# <module 'validation' from '/media/kalkyl-glob/github/masm-vali/masmvali/validation.pyc'>

# %%
DIRS = {}DIRS["even"] = '/media/kalkyl-proj/nobackup/projects/chris-mock/Project_ID793_dAmore/Sample_50ng_even/metassemble/'DIRS["uneven"] = '/media/kalkyl-proj/nobackup/projects/chris-mock/Project_ID793_dAmore/Sample_50ng_unbalanced/metassemble/'REFPHYLFILE = "/media/kalkyl-home/glob/github/masm-vali/masmvali/test/data/chris-mock/reference/phylogeny-references.tsv"REFSTATS = {}REFSTATS["even"] = "/media/kalkyl-proj/nobackup/projects/chris-mock/Project_ID793_dAmore/Sample_50ng_even/metassemble/reference-stats/ref.stats"REFSTATS["uneven"] = "/media/kalkyl-proj/nobackup/projects/chris-mock/Project_ID793_dAmore/Sample_50ng_unbalanced/metassemble/reference-stats/ref.stats"REFSETS = {}REFSETS["even"] = refgenome.ReferenceSet(REFPHYLFILE, REFSTATS["even"])REFSETS["uneven"] = refgenome.ReferenceSet(REFPHYLFILE, REFSTATS["uneven"])

# %%
ALL_STRATEGIES_ALPHA = ['velvetnoscaf','velvetscaf','velvetnoscafminimus2','velvetnoscafnewbler','velvetnoscafbambus2','velvetnoscafminimus2bambus2','velvetnoscafnewblerbambus2',         'metavelvetnoscaf','metavelvetscaf','metavelvetnoscafminimus2','metavelvetnoscafnewbler','metavelvetnoscafbambus2','metavelvetnoscafminimus2bambus2','metavelvetnoscafnewblerbambus2',         'raynoscaf','rayscaf','raynoscafminimus2','raynoscafnewbler']        POSTFIXES = [ '/noscaf/noscaf_X/ma-contigs.fa',               '/scaf/scaf_X/ma-scaffolds.fa',              '/noscaf/minimus2/ma-merge.fa',              '/noscaf/newbler/ma-merge.fa',              '/noscaf/noscaf_X/bambus2/bambus2.scaffold.linear.fasta',              '/noscaf/minimus2/bambus2/bambus2.scaffold.linear.fasta',              '/noscaf/newbler/bambus2/bambus2.scaffold.linear.fasta' ]                FILEPATHD =  dict(zip(ALL_STRATEGIES_ALPHA,                 [ item for sublist in                 [ [ '/velvet' + pf for pf in POSTFIXES ],                   [ '/metavelvet' + pf for pf in POSTFIXES ],                   [ '/ray' + pf for pf in POSTFIXES[:-3] ] ]                  for item in sublist ]))def alphafy_strat(strategy):    alpha_strat = re.sub("scaf[0-9]{2}", "scaf", strategy)    if alpha_strat not in FILEPATHD:       raise(Exception("Invalid strategy: " + alpha_strat))    else:        return alpha_strat        def has_kmer(strategy):    return len(re.sub("[a-z]", "", strategy)) > 1    def get_kmer(strategy):    # Only take first two numbers, the 2 in bambus2 can add a number    numbers = re.sub("[a-z]", "", strategy)    return int(numbers[0:2])def get_metassemble_assembly_path(d, strategy):    d = d.rstrip('/')        # Take only name without kmer number in it    fp = FILEPATHD[alphafy_strat(strategy)]            # Change X to requested kmer size    if re.search("X", fp):        fp = re.sub("X", str(get_kmer(strategy)), fp)            fp = d + '/assemblies' + fp    if not os.path.isfile(fp):        raise(Exception("Strategy " + strategy + "'s fasta file does not exist: " + fp))        return fp    def get_metassemble_assembly_validation(d, strategy, refset):    fp = get_metassemble_assembly_path(d, strategy)    return validation.AssemblyValidation(fp, "/".join(fp.split("/")[:-1]) + '/val/nucmer.coords', referenceset=refset)

# %%
MIN_KMER=21MAX_KMER=75STEPSIZE=2def add_kmers(name, postfix="", rlist=range(MIN_KMER, MAX_KMER, STEPSIZE)):    return [name + str(n) for n in rlist ]    asm_sets = {}asm_sets["contig"] = add_kmers("velvetnoscaf") + add_kmers("raynoscaf") + add_kmers("metavelvetnoscaf")asm_sets["scaf"] = add_kmers("velvetscaf") + add_kmers("rayscaf") + add_kmers("metavelvetscaf")asm_sets['contig-merge'] = [n for n in ALL_STRATEGIES_ALPHA if n.endswith('newbler') or n.endswith('minimus2')]asm_sets['contig-scaf'] = [a + "bambus2" for a in asm_sets["contig"] if not a.startswith("ray")]asm_sets['contig-merge-scaf'] = [a + "bambus2" for a in asm_sets["contig-merge"] if not a.startswith("ray")]print asm_sets['contig-merge']print [alphafy_strat(asm) for asm in asm_sets['contig-merge']]
# Out:
# ['velvetnoscafminimus2', 'velvetnoscafnewbler', 'metavelvetnoscafminimus2', 'metavelvetnoscafnewbler', 'raynoscafminimus2', 'raynoscafnewbler']
# ['velvetnoscafminimus2', 'velvetnoscafnewbler', 'metavelvetnoscafminimus2', 'metavelvetnoscafnewbler', 'raynoscafminimus2', 'raynoscafnewbler']

# %%
PLOTD = dict(zip(ALL_STRATEGIES_ALPHA,              ['k.','kv','ko','kd','k^','k*','kD',               'g.','gv','go','gd','g^','g*','gD',               'r.','rv','ro','rd']              )          )        # Change figure sizercParams['figure.figsize'] = 8, 6rcParams['figure.dpi'] = 100rcParams['savefig.dpi'] = 100def plot_purity(directory, strategies, refset):    ax = subplot(1,1,1)    for strategy in strategies:        asmv = get_metassemble_assembly_validation(directory, strategy, refset)        asmv.coords.calc_alignedbases_per_contig(asmv.contigs)        if has_kmer(strategy):            markersize = int(get_kmer(strategy) / float(MAX_KMER) * 15)        else:            markersize = 15        astrat = alphafy_strat(strategy)        plot(asmv.contigs.l50, asmv.coords.glob_pur, PLOTD[astrat], markersize=markersize, label=astrat)        # Labels    plt.xlabel('L50')    plt.ylabel('Global Purity')        # Legend    handles, labels = ax.get_legend_handles_labels()    # One label for each assembly strategy and one point shown in the legend    labelsu = list(set(labels))    handlesu = [handles[labels.index(l)] for l in labelsu]    ax.legend(handlesu, labelsu, numpoints=1, loc='lower right')        ax.set_ylim([0.8, 1.0])    ax.set_xlim([0, 14000])

# %%
# Change figure sizercParams['figure.figsize'] = 8, 6rcParams['figure.dpi'] = 100rcParams['savefig.dpi'] = 100outputdirpur = '/home/idb/github/msc-thesis/figures/notebooks/chris-mock-purity-l50'

# %%
for k in asm_sets:    print "Comparing: " + k    plot_purity(DIRS["even"], asm_sets[k], REFSETS["even"])    savefig(outputdirpur + '/' + 'even-' + k + '.png')    savefig(outputdirpur + '/' + 'even-' + k + '.pdf')    show()        plot_purity(DIRS["uneven"], asm_sets[k], REFSETS["uneven"])    savefig(outputdirpur + '/' + 'uneven-' + k + '.png')    savefig(outputdirpur + '/' + 'uneven-' + k + '.pdf')    show()
# Out:
# Comparing: contig
# Comparing: contig-merge
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /home/idb/notebooks/<ipython-input-10-32f317500998> in <module>()
#       1 for k in asm_sets:
#       2     print "Comparing: " + k
# ----> 3     plot_purity(DIRS["even"], asm_sets[k], REFSETS["even"])
#       4     savefig(outputdirpur + '/' + 'even-' + k + '.png')
#       5     savefig(outputdirpur + '/' + 'even-' + k + '.pdf')
#
# /home/idb/notebooks/<ipython-input-6-89f35a8d4e9c> in plot_purity(directory, strategies, refset)
#      14     ax = subplot(1,1,1)
#      15     for strategy in strategies:
# ---> 16         asmv = get_metassemble_assembly_validation(directory, strategy, refset)
#      17         asmv.coords.calc_alignedbases_per_contig(asmv.contigs)
#      18         if has_kmer(strategy):
#
# /home/idb/notebooks/<ipython-input-4-443f2f28b514> in get_metassemble_assembly_validation(d, strategy, refset)
#      51
#      52 def get_metassemble_assembly_validation(d, strategy, refset):
# ---> 53     fp = get_metassemble_assembly_path(d, strategy)
#      54     return validation.AssemblyValidation(fp, "/".join(fp.split("/")[:-1]) + '/val/nucmer.coords', referenceset=refset)
#
# /home/idb/notebooks/<ipython-input-4-443f2f28b514> in get_metassemble_assembly_path(d, strategy)
#      46     fp = d + '/assemblies' + fp
#      47     if not os.path.isfile(fp):
# ---> 48         raise(Exception("Strategy " + strategy + "'s fasta file does not exist: " + fp))
#      49
#      50     return fp
#
# Exception: Strategy velvetnoscaf21bambus2's fasta file does not exist: /media/kalkyl-proj/nobackup/projects/chris-mock/Project_ID793_dAmore/Sample_50ng_even/metassemble/assemblies/velvet/noscaf/noscaf_21/bambus2/bambus2.scaffold.linear.fasta
# Comparing: contig-scaf

# %%
sort([5] + [1, 3])
