# %%
# !echo "`cd /media/kalkyl-glob/github/masm-vali/masmvali/ && git log -1`"
# Out:
# commit f9c47c4b2f1c81a36137b110e214cbd7124d2906Author: Ino de Bruijn <ino.debruijn@scilifelab.se>Date:   Sat Jul 13 17:07:05 2013 +0200    Adds ROC style length distribution plot.

# %%
import sysimport osimport resys.path.append('/media/kalkyl-glob/github/masm-vali/masmvali/')import assemblyreload(assembly)import nucmerreload(nucmer)import refgenomereload(refgenome)import validationreload(validation)import warnings

# %%
DIRS = {}DIRS["even"] = '/media/kalkyl-proj/nobackup/projects/chris-mock/LIMS1884/Sample_1ng_even/metassemble/'DIRS["uneven"] = '/media/kalkyl-proj/nobackup/projects/chris-mock/LIMS1884/Sample_1ng_uneven/metassemble/'REFPHYLFILE = "/media/kalkyl-home/glob/github/masm-vali/masmvali/test/data/chris-mock/reference/phylogeny-references.tsv"REFSTATS = {}REFSTATS["even"] = "/media/kalkyl-proj/nobackup/projects/chris-mock/LIMS1884/Sample_1ng_even/metassemble/reference-stats/ref.stats"REFSTATS["uneven"] = "/media/kalkyl-proj/nobackup/projects/chris-mock/LIMS1884/Sample_1ng_uneven/metassemble/reference-stats/ref.stats"REFSETS = {}REFSETS["even"] = refgenome.ReferenceSet(REFPHYLFILE, REFSTATS["even"])REFSETS["uneven"] = refgenome.ReferenceSet(REFPHYLFILE, REFSTATS["uneven"])METAGENOME_LENGTH=195024525

# %%
ALL_STRATEGIES_ALPHA = ['velvetnoscaf','velvetscaf','velvetnoscafminimus2','velvetnoscafnewbler','velvetnoscafbambus2','velvetnoscafminimus2bambus2','velvetnoscafnewblerbambus2',         'metavelvetnoscaf','metavelvetscaf','metavelvetnoscafminimus2','metavelvetnoscafnewbler','metavelvetnoscafbambus2','metavelvetnoscafminimus2bambus2','metavelvetnoscafnewblerbambus2',         'raynoscaf','rayscaf','raynoscafminimus2','raynoscafnewbler', 'raynoscafbambus2', 'raynoscafminimus2bambus2', 'raynoscafnewblerbambus2']        POSTFIXES = [ '/noscaf/noscaf_X/ma-contigs.fa',               '/scaf/scaf_X/ma-scaffolds.fa',              '/noscaf/minimus2/ma-merge.fa',              '/noscaf/newbler/ma-merge.fa',              '/noscaf/noscaf_X/bambus2/bambus2.scaffold.linear.fasta',              '/noscaf/minimus2/bambus2/bambus2.scaffold.linear.fasta',              '/noscaf/newbler/bambus2/bambus2.scaffold.linear.fasta' ]                FILEPATHD =  dict(zip(ALL_STRATEGIES_ALPHA,                 [ item for sublist in                 [ [ '/velvet' + pf for pf in POSTFIXES ],                   [ '/metavelvet' + pf for pf in POSTFIXES ],                   [ '/ray' + pf for pf in POSTFIXES ] ]                  for item in sublist ]))def alphafy_strat(strategy):    alpha_strat = re.sub("scaf[0-9]{2}", "scaf", strategy)    if alpha_strat not in FILEPATHD:       raise(Exception("Invalid strategy: " + alpha_strat))    else:        return alpha_strat        def has_kmer(strategy):    # Should consist of 2 numbers and should not be 22 (this is minimus2bambus2)    return len(re.sub("[a-z]", "", strategy)) > 1 and int(re.sub("[a-z]", "", strategy)) != 22    def get_kmer(strategy):    # Only take first two numbers, the 2 in bambus2 can add a number    numbers = re.sub("[a-z]", "", strategy)    return int(numbers[0:2])def get_metassemble_assembly_path(d, strategy):    d = d.rstrip('/')        # Take only name without kmer number in it    fp = FILEPATHD[alphafy_strat(strategy)]            # Change X to requested kmer size    if re.search("X", fp):        fp = re.sub("X", str(get_kmer(strategy)), fp)            fp = d + '/assemblies' + fp    if not os.path.isfile(fp):        warnings.warn("Strategy " + strategy + "'s fasta file does not exist: " + fp)        return fp    def get_metassemble_assembly_validation(d, strategy, refset):    fp = get_metassemble_assembly_path(d, strategy)    return validation.AssemblyValidation(fp, "/".join(fp.split("/")[:-1]) + '/val/nucmer.coords', referenceset=refset)# returns numpy array of asm-stats.tsvdef get_metassemble_assemstats(d, strategy, MISSING_VALUE="N/A", DELIMITER="\t"):    fp = get_metassemble_assembly_path(d, strategy)    a = np.genfromtxt("/".join(fp.split("/")[:-1]) + '/val/asm-stats.tsv', names=True, dtype=None, missing_values=MISSING_VALUE, usemask=True, delimiter=DELIMITER)    return a

# %%
MIN_KMER=21MAX_KMER=75STEPSIZE=2def add_kmers(name, postfix="", rlist=range(MIN_KMER, MAX_KMER, STEPSIZE)):    return [name + str(n) for n in rlist ]def get_max_l50(d, strategies):    def get_l50(s):        try:            rv = get_metassemble_assemstats(d, s)["l50"]        except IOError:            warnings.warn("asmstats of " + s + " does not exist")            rv = 0        return rv                return max(strategies, key=get_l50)asm_sets = {}for k in DIRS:    asm_sets[k] = {}    asm_sets[k]["contig"] = [get_max_l50(DIRS[k], add_kmers(s)) for s in ["raynoscaf", "velvetnoscaf", "metavelvetnoscaf"]]    asm_sets[k]["scaf"] = [get_max_l50(DIRS[k], add_kmers(s)) for s in ["rayscaf", "velvetscaf", "metavelvetscaf"]]    asm_sets[k]['contig-merge'] = [n for n in ALL_STRATEGIES_ALPHA if n.endswith('newbler') or n.endswith('minimus2')]    asm_sets[k]['contig-scaf'] = [get_max_l50(DIRS[k], [a + "bambus2" for a in add_kmers(s)]) for s in ["raynoscaf", "velvetnoscaf", "metavelvetnoscaf"]]    asm_sets[k]['contig-merge-scaf'] = [a + "bambus2" for a in asm_sets[k]["contig-merge"]]for k in DIRS:    print k    print asm_sets[k]['contig']    print asm_sets[k]['contig-scaf']
# Out:
# -c:13: UserWarning: asmstats of raynoscaf23bambus2 does not exist-c:49: UserWarning: Strategy raynoscaf21bambus2's fasta file does not exist: /media/kalkyl-proj/nobackup/projects/chris-mock/LIMS1884/Sample_1ng_uneven/metassemble/assemblies/ray/noscaf/noscaf_21/bambus2/bambus2.scaffold.linear.fasta
# -c:13: UserWarning: asmstats of raynoscaf21bambus2 does not exist-c:49: UserWarning: Strategy raynoscaf27bambus2's fasta file does not exist: /media/kalkyl-proj/nobackup/projects/chris-mock/LIMS1884/Sample_1ng_uneven/metassemble/assemblies/ray/noscaf/noscaf_27/bambus2/bambus2.scaffold.linear.fasta
# -c:13: UserWarning: asmstats of raynoscaf27bambus2 does not exist-c:49: UserWarning: Strategy raynoscaf43bambus2's fasta file does not exist: /media/kalkyl-proj/nobackup/projects/chris-mock/LIMS1884/Sample_1ng_uneven/metassemble/assemblies/ray/noscaf/noscaf_43/bambus2/bambus2.scaffold.linear.fasta
# ...

# %%
PLOTD = dict(zip(ALL_STRATEGIES_ALPHA,              ['k-','k-','k--','k-','k-','k--','k-',               'g-','g-','g--','g-','g-','g--','g-',               'r-','r-','r--','r-','r-','r--','r-']              )          )        # Change figure sizercParams['figure.figsize'] = 8, 6rcParams['figure.dpi'] = 100rcParams['savefig.dpi'] = 100def plot_length(directory, strategies, refset, cut_off=100):    ax = subplot(1,1,1)    for strategy in strategies:        contigs = assembly.ContigDict()        fp = get_metassemble_assembly_path(directory, strategy)        if os.path.isfile(fp):            contigs.parse_fasta_lengths(fp)            contiglens = [c.length for c in contigs.itervalues()]            contiglens.sort()            contiglens.reverse()            cla = np.array(contiglens)            clacs = np.cumsum(cla[cla > cut_off])                # Plot contig length vs sum of bases        astrat = alphafy_strat(strategy)        plot(cla[cla > cut_off], clacs, PLOTD[astrat], label=astrat, linewidth=2.0)                # Add L50        l50 = cla[cla > cut_off][clacs >= clacs[len(clacs)-1]/2][0]        plot(l50, clacs[clacs >= clacs[len(clacs)-1]/2][0], PLOTD[astrat][0] + "o", markersize=10)    ax.set_xscale('log')    ax.set_ylim([0,METAGENOME_LENGTH])    plt.gca().invert_xaxis()    # Labels    plt.xlabel('Contig/Scaffold length')    plt.ylabel('Sum of bases')    # Legend    handles, labels = ax.get_legend_handles_labels()    ax.legend(handles, labels, loc='upper left') # or lower right    #ax.set_yscale('log')    ax.set_xlim([10**6,10**2])

# %%
outputdir = '/media/kalkyl-glob/github/masmvali-publication/figures/notebooks/lims1884-length-distribution'for k in DIRS:    for kj in asm_sets[k]:        print "Comparing: " + k + " " + kj        plot_length(DIRS[k], asm_sets[k][kj], REFSETS[k])        savefig(outputdir + '/' + k + '-' + kj + '.png')        savefig(outputdir + '/' + k + '-' + kj + '.pdf')        show()
# Out:
# Comparing: even contig
# Comparing: even contig-merge
# Comparing: even contig-scaf
# Comparing: even contig-merge-scaf
# Comparing: even scaf
# Comparing: uneven contig
# Comparing: uneven contig-merge
# Comparing: uneven contig-scaf
# Comparing: uneven contig-merge-scaf
# -c:49: UserWarning: Strategy velvetnoscafnewblerbambus2's fasta file does not exist: /media/kalkyl-proj/nobackup/projects/chris-mock/LIMS1884/Sample_1ng_uneven/metassemble/assemblies/velvet/noscaf/newbler/bambus2/bambus2.scaffold.linear.fasta
# Comparing: uneven scaf

# %%
def plot_length_vs_metagenome_cov(directory, strategies, refset, cut_off=100):        #lengthsa = np.array([item for sublist in map(lambda x: range(10**x,10**(x+1),10**x),range(2,7)) for item in sublist])     ax = subplot(1,1,1)    for strategy in strategies:        fp = get_metassemble_assembly_path(directory, strategy)        if os.path.isfile(fp):            contigs = assembly.ContigDict()            contigs.parse_fasta_lengths(fp)                    lengthsa = sort([item for sublist in map(lambda x: (range(10**x, 10**(x+1), (10**(x+1)-10**x) /4)), range(2,6)) for item in sublist ] + [10**6] + [contigs.l50])                    # Determine coverage            c_cova = np.copy(lengthsa)            c = nucmer.Coords("/".join(fp.split("/")[:-1]) + '/val/nucmer.coords')            astrat = alphafy_strat(strategy)            for j in xrange(len(c_cova)):                c.calc_genome_contig_cov_in_bases(refset, cut_off=int(lengthsa[j]), count_contig_once=True)                c_cova[j] = (c.ref_sum_cov * 100) / c.ref_sum_bases                plot(lengthsa, c_cova, PLOTD[astrat], label=astrat, linewidth=2.0)                #plot(contigs.l50, c_cova[lengthsa == contigs.l50], PLOTD[astrat][0] + 'o', markersize=10)        ax.set_xscale('log')    plt.gca().invert_xaxis()    # Labels    plt.ylabel('Metagenome coverage')    plt.xlabel('Contig/Scaffold length')    # Legend    handles, labels = ax.get_legend_handles_labels()    ax.legend(handles, labels, numpoints=1, loc='upper left')        ax.set_ylim([0,100])    ax.set_xlim([10**6,0])

# %%
outputdir = '/media/kalkyl-glob/github/masmvali-publication/figures/notebooks/lims1884-length-distribution-cov'for k in DIRS:    for kj in asm_sets[k]:        print "Comparing: " + k + " " + kj        plot_length_vs_metagenome_cov(DIRS[k], asm_sets[k][kj], REFSETS[k].refs)        savefig(outputdir + '/' + k + '-' + kj + '.png')        savefig(outputdir + '/' + k + '-' + kj + '.pdf')        show()
# Out:
# Comparing: uneven contig-merge
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/idb/github/msc-thesis/notebooks/<ipython-input-49-86981c935388> in <module>()
#       4     for kj in asm_sets[k]:
#       5         print "Comparing: " + k + " " + kj
# ----> 6         plot_length_vs_metagenome_cov(DIRS[k], asm_sets[k][kj], REFSETS[k])
#       7         savefig(outputdir + '/' + k + '-' + kj + '.png')
#       8         savefig(outputdir + '/' + k + '-' + kj + '.pdf')
#
# /home/idb/github/msc-thesis/notebooks/<ipython-input-48-d90e51f8647a> in plot_length_vs_metagenome_cov(directory, strategies, refset, cut_off)
#      16             astrat = alphafy_strat(strategy)
#      17             for j in xrange(len(c_cova)):
# ---> 18                 c.calc_genome_contig_cov_in_bases(refset.refs, cut_off=int(lengthsa[j]), count_contig_once=True)
# ...
